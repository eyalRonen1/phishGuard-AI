# %%
# Load the original data into a DataFrame
df = pd.read_csv('datasetupdated.csv')

# %%
df
# Out:
#                                               Email Text      Email Type
# 0      \nHello I am your hot lil horny toy.\n    I am...  Phishing Email
# 1      software at incredibly low prices ( 86 % lower...  Phishing Email
# 2      entourage , stockmogul newsletter ralph velez ...  Phishing Email
# 3      we owe you lots of money dear applicant , afte...  Phishing Email
# 4      make her beg you to give it to her everynight ...  Phishing Email
# ...                                                  ...             ...
# 18583                                              empty      Safe Email
# 18584  \nRick Moen  a ֳƒֲ©crit:> > I'm confused. I th...      Safe Email
# 18585  request submitted : access request for anita ....      Safe Email
# 18586  re : important - prc mtg hi dorn & john , as y...      Safe Email
# 18587  press clippings - letter on californian utilit...      Safe Email
#
# [18588 rows x 2 columns]

# %%
df['Email Type'] = df['Email Type'].replace({'Phishing Email': 1, 'Safe Email': 0})
df
# Out:
#                                               Email Text  Email Type
# 0      \nHello I am your hot lil horny toy.\n    I am...           1
# 1      software at incredibly low prices ( 86 % lower...           1
# 2      entourage , stockmogul newsletter ralph velez ...           1
# 3      we owe you lots of money dear applicant , afte...           1
# 4      make her beg you to give it to her everynight ...           1
# ...                                                  ...         ...
# 18583                                              empty           0
# 18584  \nRick Moen  a ֳƒֲ©crit:> > I'm confused. I th...           0
# 18585  request submitted : access request for anita ....           0
# 18586  re : important - prc mtg hi dorn & john , as y...           0
# 18587  press clippings - letter on californian utilit...           0
#
# [18588 rows x 2 columns]

# %%
df.to_csv('cleaned_phishing_data_test.csv', index=False)
